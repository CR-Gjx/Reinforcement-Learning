# %%
# %matplotlib inline

import gym
import numpy as np
from matplotlib import pyplot as plt
# Out:
# /home/gjx/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-260750ed3c16> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
#       2
# ----> 3 import gym
#       4 import numpy as np
#       5 from matplotlib import pyplot as plt
#
# ImportError: No module named gym

# %%
env = gym.envs.make("Breakout-v0")
# Out:
# INFO:gym.envs.registration:Making new env: Breakout-v0
# [2017-02-20 14:48:49,140] Making new env: Breakout-v0
# ---------------------------------------------------------------------------
# DependencyNotInstalled                    Traceback (most recent call last)
# <ipython-input-4-4bffd428d9e8> in <module>()
# ----> 1 env = gym.envs.make("Breakout-v0")
#
# C:\Anaconda2\lib\site-packages\gym\envs\registration.pyc in make(id)
#     138
#     139 def make(id):
# --> 140     return registry.make(id)
#     141
#     142 def spec(id):
#
# C:\Anaconda2\lib\site-packages\gym\envs\registration.pyc in make(self, id)
#     103         logger.info('Making new env: %s', id)
#     104         spec = self.spec(id)
# --> 105         return spec.make()
#     106
#     107     def all(self):
#
# C:\Anaconda2\lib\site-packages\gym\envs\registration.pyc in make(self)
#      67             raise error.Error('Attempting to make deprecated env {}. (HINT: is there a newer registered version of this env?)'.format(self.id))
#      68
# ---> 69         cls = load(self._entry_point)
#      70         env = cls(**self._kwargs)
#      71
#
# C:\Anaconda2\lib\site-packages\gym\envs\registration.pyc in load(name)
#      16 def load(name):
#      17     entry_point = pkg_resources.EntryPoint.parse('x={}'.format(name))
# ---> 18     result = entry_point.load(False)
#      19     return result
#      20
#
# C:\Anaconda2\lib\site-packages\setuptools-23.0.0-py2.7.egg\pkg_resources\__init__.py in load(self, require, *args, **kwargs)
#    2227         if require:
#    2228             self.require(*args, **kwargs)
# -> 2229         return self.resolve()
#    2230
#    2231     def resolve(self):
#
# C:\Anaconda2\lib\site-packages\setuptools-23.0.0-py2.7.egg\pkg_resources\__init__.py in resolve(self)
#    2233         Resolve the entry point from its module and attrs.
#    2234         """
# -> 2235         module = __import__(self.module_name, fromlist=['__name__'], level=0)
#    2236         try:
#    2237             return functools.reduce(getattr, self.attrs, module)
#
# C:\Anaconda2\lib\site-packages\gym\envs\atari\__init__.py in <module>()
# ----> 1 from gym.envs.atari.atari_env import AtariEnv
#
# C:\Anaconda2\lib\site-packages\gym\envs\atari\atari_env.py in <module>()
#       9     import atari_py
#      10 except ImportError as e:
# ---> 11     raise error.DependencyNotInstalled("{}. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)".format(e))
#      12
#      13 import logging
#
# DependencyNotInstalled: No module named atari_py. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)

# %%
print("Action space size: {}".format(env.action_space.n))
print(env.get_action_meanings())

observation = env.reset()
print("Observation space shape: {}".format(observation.shape))

plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(2) for x in range(1)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

env.render(close=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6846dace0730> in <module>()
# ----> 1 print("Action space size: {}".format(env.action_space.n))
#       2 print(env.get_action_meanings())
#       3
#       4 observation = env.reset()
#       5 print("Observation space shape: {}".format(observation.shape))
#
# NameError: name 'env' is not defined

# %%
# Check out what a cropped image looks like
plt.imshow(observation[34:-16,:,:])
